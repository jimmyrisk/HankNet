# %%
import torch
from collections import deque
import numpy as np
from copy import deepcopy
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use('classic')

from plot_tools import *

# %%
lawn_num = 22
run_id = 10000
reward_function = 2
go_explore = 'True'

# %%
fig, axs = plt.subplots(1, 1, sharex=True, sharey=False, figsize=(16, 8))#, figsize=(10, 4))

#plot_loss(lawn_num = 22,
plot_reward(lawn_num = lawn_num,
            run_id = run_id,
            reward_function = reward_function,
            go_explore = go_explore,
            ax = axs)

axs.set_title(f"Run ID: {run_id}, GoExplore: {go_explore}")
# Out:
# Text(0.5, 1.0, 'Run ID: 10000, GoExplore: True')
